# %%
# %%capture
# !pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install tqdm
# !pip install scipy
# !pip install opencv-python
# !pip install scikit-image
# !pip install tensorboard
# !pip install matplotlib
# !pip install timm==0.5.4
# !pip install transformers datasets torch torchvision gdown

# %%
import argparse
import torch
import numpy as np
import logging
from pathlib import Path
import torch.nn as nn

# %%
# !git clone https://github.com/gangweix/IGEV-plusplus/
# Out:
# Cloning into 'IGEV-plusplus'...
# remote: Enumerating objects: 284, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 284 (delta 46), reused 0 (delta 0), pack-reused 199 (from 1)
# Receiving objects: 100% (284/284), 17.56 MiB | 21.77 MiB/s, done.
# Resolving deltas: 100% (150/150), done.

# %%
# Descargando el archivo kitti15.pth. Kitti15 is the pretrained weights with KITTI dataset.
import gdown
file_id = "1VG47N7gPzkg-FIhge0XHtlOVHDVmMdek"
gdown.download(f"https://drive.google.com/uc?id={file_id}", output="/content/kitti15.pth", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1VG47N7gPzkg-FIhge0XHtlOVHDVmMdek
# From (redirected): https://drive.google.com/uc?id=1VG47N7gPzkg-FIhge0XHtlOVHDVmMdek&confirm=t&uuid=9a88f9d8-b091-4826-a4a4-371b05758de3
# To: /content/kitti15.pth
# 100%|██████████| 50.8M/50.8M [00:00<00:00, 106MB/s]
# '/content/kitti15.pth'

# %%
def Args():
    parser = argparse.ArgumentParser()
    parser.add_argument('--name', default='igev-stereo', help="name your experiment")
    parser.add_argument('--restore_ckpt', default=None, help='load the weights from a specific checkpoint')
    parser.add_argument('--logdir', default='./checkpoints', help='the directory to save logs and checkpoints')
    parser.add_argument('--mixed_precision', default=True, action='store_true', help='use mixed precision')
    parser.add_argument('--precision_dtype', default='float16', choices=['float16', 'bfloat16', 'float32'], help='Choose precision type: float16 or bfloat16 or float32')

    # Training parameters
    parser.add_argument('--batch_size', type=int, default=8, help="batch size used during training.")
    parser.add_argument('--train_datasets', default='sceneflow', choices=['sceneflow', 'kitti', 'middlebury_train', 'middlebury_finetune', 'eth3d_train', 'eth3d_finetune'], help="training datasets.")
    parser.add_argument('--lr', type=float, default=0.0002, help="max learning rate.")
    parser.add_argument('--num_steps', type=int, default=200000, help="length of training schedule.")
    parser.add_argument('--image_size', type=int, nargs='+', default=[256, 768], help="size of the random image crops used during training.")
    parser.add_argument('--train_iters', type=int, default=22, help="number of updates to the disparity field in each forward pass.")
    parser.add_argument('--wdecay', type=float, default=.00001, help="Weight decay in optimizer.")

    # Validation parameters
    parser.add_argument('--valid_iters', type=int, default=32, help='number of flow-field updates during validation forward pass')

    # Architecure choices
    parser.add_argument('--corr_levels', type=int, default=2, help="number of levels in the correlation pyramid")
    parser.add_argument('--corr_radius', type=int, default=4, help="width of the correlation pyramid")
    parser.add_argument('--n_downsample', type=int, default=2, help="resolution of the disparity field (1/2^K)")
    parser.add_argument('--n_gru_layers', type=int, default=3, help="number of hidden GRU levels")
    parser.add_argument('--hidden_dims', nargs='+', type=int, default=[128]*3, help="hidden state and context dimensions")
    parser.add_argument('--max_disp', type=int, default=768, help="max disp range")
    parser.add_argument('--s_disp_range', type=int, default=48, help="max disp of small disparity-range geometry encoding volume")
    parser.add_argument('--m_disp_range', type=int, default=96, help="max disp of medium disparity-range geometry encoding volume")
    parser.add_argument('--l_disp_range', type=int, default=192, help="max disp of large disparity-range geometry encoding volume")
    parser.add_argument('--s_disp_interval', type=int, default=1, help="disp interval of small disparity-range geometry encoding volume")
    parser.add_argument('--m_disp_interval', type=int, default=2, help="disp interval of medium disparity-range geometry encoding volume")
    parser.add_argument('--l_disp_interval', type=int, default=4, help="disp interval of large disparity-range geometry encoding volume")

    # Data augmentation
    parser.add_argument('--img_gamma', type=float, nargs='+', default=None, help="gamma range")
    parser.add_argument('--saturation_range', type=float, nargs='+', default=[0, 1.4], help='color saturation')
    parser.add_argument('--do_flip', default=False, choices=['h', 'v'], help='flip the images horizontally or vertically')
    parser.add_argument('--spatial_scale', type=float, nargs='+', default=[-0.4, 0.8], help='re-scale the images randomly')
    parser.add_argument('--noyjitter', action='store_true', help='don\'t simulate imperfect rectification')
    args = parser.parse_args()

    torch.manual_seed(666)
    np.random.seed(666)

    logging.basicConfig(level=logging.INFO,
                        format='%(asctime)s %(levelname)-8s [%(filename)s:%(lineno)d] %(message)s')

    Path(args.logdir).mkdir(exist_ok=True, parents=True)
    # train(args)
    return args

# %%
"""
--name                  # Name of the experiment (default: 'igev-stereo')
--restore_ckpt          # Path to a checkpoint to resume training (default: None)
--logdir                # Directory to save logs and checkpoints (default: './checkpoints')
--mixed_precision       # Enable mixed precision training (default: True)
--precision_dtype       # Precision type: 'float16', 'bfloat16', or 'float32' (default: 'float16')

--batch_size            # Batch size (default: 8)
--train_datasets        # Dataset for training (choices: 'sceneflow', 'kitti', 'middlebury_train', 'middlebury_finetune', 'eth3d_train', 'eth3d_finetune'; default: 'sceneflow')
--lr                    # Learning rate (default: 0.0002)
--num_steps             # Total training steps (default: 200000)
--image_size            # Size of random image crops (default: [256, 768])
--train_iters           # Number of disparity updates per forward pass (default: 22)
--wdecay                # Weight decay (default: 0.00001)

--valid_iters           # Number of disparity updates during validation (default: 32)

--corr_levels           # Number of levels in the correlation pyramid (default: 2)
--corr_radius           # Width of the correlation pyramid (default: 4)
--n_downsample          # Downsampling factor for disparity field (default: 2)
--n_gru_layers          # Number of GRU layers (default: 3)
--hidden_dims           # Hidden dimensions for GRU layers (default: [128, 128, 128])
--max_disp              # Maximum disparity range (default: 768)
--s_disp_range          # Max disparity for small-range volume (default: 48)
--m_disp_range          # Max disparity for medium-range volume (default: 96)
--l_disp_range          # Max disparity for large-range volume (default: 192)
--s_disp_interval       # Disparity interval for small-range volume (default: 1)
--m_disp_interval       # Disparity interval for medium-range volume (default: 2)
--l_disp_interval       # Disparity interval for large-range volume (default: 4)

--img_gamma             # Gamma correction range (default: None)
--saturation_range      # Color saturation range (default: [0, 1.4])
--do_flip               # Flip images ('h' for horizontal, 'v' for vertical) (default: False)
--spatial_scale         # Random image rescaling range (default: [-0.4, 0.8])
--noyjitter             # Disable imperfect rectification simulation (default: False)

"""

# %%
import sys
import os

# Add the root of the repository to sys.path
repo_path = '/content/IGEV-plusplus/'
sys.path.append(repo_path)

from core import igev_stereo


from igev_stereo import IGEVStereo

args = Args() # Create an instance of Args

model = igev_stereo.IGEVStereo(args) # Instantiate the model

pretrained_ckpt_path = "/content/checkpoints/pretrained_models/kitti15.pth"

# %%
for name, module in model.named_modules():
    if isinstance(module, nn.Linear):
        print(name)
for name, module in model.named_modules():
    print(f"{name}: {type(module)}")
# Out:
# : <class 'core.igev_stereo.IGEVStereo'>
# cnet: <class 'core.extractor.MultiBasicEncoder'>
# cnet.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.relu1: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer1: <class 'torch.nn.modules.container.Sequential'>
# cnet.layer1.0: <class 'core.extractor.ResidualBlock'>
# cnet.layer1.0.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer1.0.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer1.0.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer1.0.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer1.0.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer1.1: <class 'core.extractor.ResidualBlock'>
# cnet.layer1.1.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer1.1.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer1.1.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer1.1.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer1.1.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer2: <class 'torch.nn.modules.container.Sequential'>
# cnet.layer2.0: <class 'core.extractor.ResidualBlock'>
# cnet.layer2.0.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer2.0.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer2.0.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer2.0.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer2.0.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer2.0.norm3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer2.0.downsample: <class 'torch.nn.modules.container.Sequential'>
# cnet.layer2.0.downsample.0: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer2.1: <class 'core.extractor.ResidualBlock'>
# cnet.layer2.1.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer2.1.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer2.1.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer2.1.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer2.1.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer3: <class 'torch.nn.modules.container.Sequential'>
# cnet.layer3.0: <class 'core.extractor.ResidualBlock'>
# cnet.layer3.0.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer3.0.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer3.0.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer3.0.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer3.0.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer3.0.norm3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer3.0.downsample: <class 'torch.nn.modules.container.Sequential'>
# cnet.layer3.0.downsample.0: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer3.1: <class 'core.extractor.ResidualBlock'>
# cnet.layer3.1.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer3.1.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer3.1.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer3.1.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer3.1.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer4: <class 'torch.nn.modules.container.Sequential'>
# cnet.layer4.0: <class 'core.extractor.ResidualBlock'>
# cnet.layer4.0.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer4.0.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer4.0.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer4.0.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer4.0.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer4.0.norm3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer4.0.downsample: <class 'torch.nn.modules.container.Sequential'>
# cnet.layer4.0.downsample.0: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer4.1: <class 'core.extractor.ResidualBlock'>
# cnet.layer4.1.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer4.1.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer4.1.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer4.1.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer4.1.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer5: <class 'torch.nn.modules.container.Sequential'>
# cnet.layer5.0: <class 'core.extractor.ResidualBlock'>
# cnet.layer5.0.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer5.0.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer5.0.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer5.0.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer5.0.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer5.0.norm3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer5.0.downsample: <class 'torch.nn.modules.container.Sequential'>
# cnet.layer5.0.downsample.0: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer5.1: <class 'core.extractor.ResidualBlock'>
# cnet.layer5.1.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer5.1.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.layer5.1.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.layer5.1.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.layer5.1.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.outputs04: <class 'torch.nn.modules.container.ModuleList'>
# cnet.outputs04.0: <class 'torch.nn.modules.container.Sequential'>
# cnet.outputs04.0.0: <class 'core.extractor.ResidualBlock'>
# cnet.outputs04.0.0.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs04.0.0.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs04.0.0.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.outputs04.0.0.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.outputs04.0.0.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.outputs04.0.1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs04.1: <class 'torch.nn.modules.container.Sequential'>
# cnet.outputs04.1.0: <class 'core.extractor.ResidualBlock'>
# cnet.outputs04.1.0.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs04.1.0.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs04.1.0.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.outputs04.1.0.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.outputs04.1.0.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.outputs04.1.1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs08: <class 'torch.nn.modules.container.ModuleList'>
# cnet.outputs08.0: <class 'torch.nn.modules.container.Sequential'>
# cnet.outputs08.0.0: <class 'core.extractor.ResidualBlock'>
# cnet.outputs08.0.0.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs08.0.0.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs08.0.0.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.outputs08.0.0.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.outputs08.0.0.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.outputs08.0.1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs08.1: <class 'torch.nn.modules.container.Sequential'>
# cnet.outputs08.1.0: <class 'core.extractor.ResidualBlock'>
# cnet.outputs08.1.0.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs08.1.0.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs08.1.0.relu: <class 'torch.nn.modules.activation.ReLU'>
# cnet.outputs08.1.0.norm1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.outputs08.1.0.norm2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# cnet.outputs08.1.1: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs16: <class 'torch.nn.modules.container.ModuleList'>
# cnet.outputs16.0: <class 'torch.nn.modules.conv.Conv2d'>
# cnet.outputs16.1: <class 'torch.nn.modules.conv.Conv2d'>
# update_block: <class 'core.update.BasicMultiUpdateBlock'>
# update_block.geo_encoder0: <class 'core.update.GeoEncoder'>
# update_block.geo_encoder0.convg1: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.geo_encoder0.convg2: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.geo_encoder0.relu: <class 'torch.nn.modules.activation.ReLU'>
# update_block.geo_encoder1: <class 'core.update.GeoEncoder'>
# update_block.geo_encoder1.convg1: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.geo_encoder1.convg2: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.geo_encoder1.relu: <class 'torch.nn.modules.activation.ReLU'>
# update_block.geo_encoder2: <class 'core.update.GeoEncoder'>
# update_block.geo_encoder2.convg1: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.geo_encoder2.convg2: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.geo_encoder2.relu: <class 'torch.nn.modules.activation.ReLU'>
# update_block.encoder: <class 'core.update.BasicDispEncoder'>
# update_block.encoder.convc1: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.encoder.convc2: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.encoder.convd1: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.encoder.convd2: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.encoder.conv: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.gru04: <class 'core.update.ConvGRU'>
# update_block.gru04.convz: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.gru04.convr: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.gru04.convq: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.gru08: <class 'core.update.ConvGRU'>
# update_block.gru08.convz: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.gru08.convr: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.gru08.convq: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.gru16: <class 'core.update.ConvGRU'>
# update_block.gru16.convz: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.gru16.convr: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.gru16.convq: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.disp_head: <class 'core.update.DispHead'>
# update_block.disp_head.conv1: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.disp_head.conv2: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.disp_head.relu: <class 'torch.nn.modules.activation.ReLU'>
# update_block.mask_feat_4: <class 'torch.nn.modules.container.Sequential'>
# update_block.mask_feat_4.0: <class 'torch.nn.modules.conv.Conv2d'>
# update_block.mask_feat_4.1: <class 'torch.nn.modules.activation.ReLU'>
# context_zqr_convs: <class 'torch.nn.modules.container.ModuleList'>
# context_zqr_convs.0: <class 'torch.nn.modules.conv.Conv2d'>
# context_zqr_convs.1: <class 'torch.nn.modules.conv.Conv2d'>
# context_zqr_convs.2: <class 'torch.nn.modules.conv.Conv2d'>
# feature: <class 'core.extractor.Feature'>
# feature.conv_stem: <class 'torch.nn.modules.conv.Conv2d'>
# feature.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block0: <class 'torch.nn.modules.container.Sequential'>
# feature.block0.0: <class 'torch.nn.modules.container.Sequential'>
# feature.block0.0.0: <class 'timm.models.efficientnet_blocks.DepthwiseSeparableConv'>
# feature.block0.0.0.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block0.0.0.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block0.0.0.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block0.0.0.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block0.0.0.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block0.0.0.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block0.0.0.act2: <class 'torch.nn.modules.linear.Identity'>
# feature.block1: <class 'torch.nn.modules.container.Sequential'>
# feature.block1.0: <class 'torch.nn.modules.container.Sequential'>
# feature.block1.0.0: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block1.0.0.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block1.0.0.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block1.0.0.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block1.0.0.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block1.0.0.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block1.0.0.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block1.0.0.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block1.0.0.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block1.0.0.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block1.0.1: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block1.0.1.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block1.0.1.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block1.0.1.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block1.0.1.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block1.0.1.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block1.0.1.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block1.0.1.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block1.0.1.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block1.0.1.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block2: <class 'torch.nn.modules.container.Sequential'>
# feature.block2.0: <class 'torch.nn.modules.container.Sequential'>
# feature.block2.0.0: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block2.0.0.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block2.0.0.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block2.0.0.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block2.0.0.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block2.0.0.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block2.0.0.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block2.0.0.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block2.0.0.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block2.0.0.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block2.0.1: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block2.0.1.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block2.0.1.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block2.0.1.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block2.0.1.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block2.0.1.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block2.0.1.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block2.0.1.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block2.0.1.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block2.0.1.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block2.0.2: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block2.0.2.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block2.0.2.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block2.0.2.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block2.0.2.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block2.0.2.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block2.0.2.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block2.0.2.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block2.0.2.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block2.0.2.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3: <class 'torch.nn.modules.container.Sequential'>
# feature.block3.0: <class 'torch.nn.modules.container.Sequential'>
# feature.block3.0.0: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block3.0.0.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.0.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.0.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.0.0.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.0.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.0.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.0.0.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block3.0.0.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.0.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.1: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block3.0.1.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.1.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.1.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.0.1.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.1.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.1.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.0.1.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block3.0.1.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.1.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.2: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block3.0.2.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.2.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.2.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.0.2.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.2.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.2.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.0.2.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block3.0.2.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.2.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.3: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block3.0.3.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.3.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.3.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.0.3.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.3.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.0.3.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.0.3.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block3.0.3.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.0.3.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.1: <class 'torch.nn.modules.container.Sequential'>
# feature.block3.1.0: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block3.1.0.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.1.0.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.1.0.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.1.0.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.1.0.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.1.0.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.1.0.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block3.1.0.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.1.0.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.1.1: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block3.1.1.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.1.1.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.1.1.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.1.1.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.1.1.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.1.1.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.1.1.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block3.1.1.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.1.1.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.1.2: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block3.1.2.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.1.2.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.1.2.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.1.2.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.1.2.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block3.1.2.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block3.1.2.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block3.1.2.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block3.1.2.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block4: <class 'torch.nn.modules.container.Sequential'>
# feature.block4.0: <class 'torch.nn.modules.container.Sequential'>
# feature.block4.0.0: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block4.0.0.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block4.0.0.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block4.0.0.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block4.0.0.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block4.0.0.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block4.0.0.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block4.0.0.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block4.0.0.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block4.0.0.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block4.0.1: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block4.0.1.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block4.0.1.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block4.0.1.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block4.0.1.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block4.0.1.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block4.0.1.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block4.0.1.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block4.0.1.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block4.0.1.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block4.0.2: <class 'timm.models.efficientnet_blocks.InvertedResidual'>
# feature.block4.0.2.conv_pw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block4.0.2.bn1: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block4.0.2.act1: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block4.0.2.conv_dw: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block4.0.2.bn2: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.block4.0.2.act2: <class 'torch.nn.modules.activation.ReLU6'>
# feature.block4.0.2.se: <class 'torch.nn.modules.linear.Identity'>
# feature.block4.0.2.conv_pwl: <class 'torch.nn.modules.conv.Conv2d'>
# feature.block4.0.2.bn3: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# feature.deconv32_16: <class 'core.submodule.Conv2x'>
# feature.deconv32_16.conv1: <class 'core.submodule.BasicConv'>
# feature.deconv32_16.conv1.conv: <class 'torch.nn.modules.conv.ConvTranspose2d'>
# feature.deconv32_16.conv1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# feature.deconv32_16.conv2: <class 'core.submodule.BasicConv'>
# feature.deconv32_16.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# feature.deconv32_16.conv2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# feature.deconv16_8: <class 'core.submodule.Conv2x'>
# feature.deconv16_8.conv1: <class 'core.submodule.BasicConv'>
# feature.deconv16_8.conv1.conv: <class 'torch.nn.modules.conv.ConvTranspose2d'>
# feature.deconv16_8.conv1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# feature.deconv16_8.conv2: <class 'core.submodule.BasicConv'>
# feature.deconv16_8.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# feature.deconv16_8.conv2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# feature.deconv8_4: <class 'core.submodule.Conv2x'>
# feature.deconv8_4.conv1: <class 'core.submodule.BasicConv'>
# feature.deconv8_4.conv1.conv: <class 'torch.nn.modules.conv.ConvTranspose2d'>
# feature.deconv8_4.conv1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# feature.deconv8_4.conv2: <class 'core.submodule.BasicConv'>
# feature.deconv8_4.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# feature.deconv8_4.conv2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# feature.conv4: <class 'core.submodule.BasicConv'>
# feature.conv4.conv: <class 'torch.nn.modules.conv.Conv2d'>
# feature.conv4.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# stem_2: <class 'torch.nn.modules.container.Sequential'>
# stem_2.0: <class 'core.submodule.BasicConv'>
# stem_2.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# stem_2.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# stem_2.1: <class 'torch.nn.modules.conv.Conv2d'>
# stem_2.2: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# stem_2.3: <class 'torch.nn.modules.activation.ReLU'>
# stem_4: <class 'torch.nn.modules.container.Sequential'>
# stem_4.0: <class 'core.submodule.BasicConv'>
# stem_4.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# stem_4.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# stem_4.1: <class 'torch.nn.modules.conv.Conv2d'>
# stem_4.2: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# stem_4.3: <class 'torch.nn.modules.activation.ReLU'>
# spx: <class 'torch.nn.modules.container.Sequential'>
# spx.0: <class 'torch.nn.modules.conv.ConvTranspose2d'>
# spx_2: <class 'core.submodule.Conv2x'>
# spx_2.conv1: <class 'core.submodule.BasicConv'>
# spx_2.conv1.conv: <class 'torch.nn.modules.conv.ConvTranspose2d'>
# spx_2.conv1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# spx_2.conv2: <class 'core.submodule.BasicConv'>
# spx_2.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# spx_2.conv2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# spx_4: <class 'torch.nn.modules.container.Sequential'>
# spx_4.0: <class 'core.submodule.BasicConv'>
# spx_4.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# spx_4.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# spx_4.1: <class 'torch.nn.modules.conv.Conv2d'>
# spx_4.2: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# spx_4.3: <class 'torch.nn.modules.activation.ReLU'>
# spx_2_gru: <class 'core.submodule.Conv2x'>
# spx_2_gru.conv1: <class 'core.submodule.BasicConv'>
# spx_2_gru.conv1.conv: <class 'torch.nn.modules.conv.ConvTranspose2d'>
# spx_2_gru.conv1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# spx_2_gru.conv2: <class 'core.submodule.BasicConv'>
# spx_2_gru.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# spx_2_gru.conv2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# spx_gru: <class 'torch.nn.modules.container.Sequential'>
# spx_gru.0: <class 'torch.nn.modules.conv.ConvTranspose2d'>
# conv: <class 'core.submodule.BasicConv'>
# conv.conv: <class 'torch.nn.modules.conv.Conv2d'>
# conv.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# desc: <class 'torch.nn.modules.conv.Conv2d'>
# patch0: <class 'torch.nn.modules.conv.Conv3d'>
# patch1: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0: <class 'core.igev_stereo.hourglass'>
# cost_agg0.conv0: <class 'core.submodule.BasicConv'>
# cost_agg0.conv0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.conv0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.conv1: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.conv1.0: <class 'core.submodule.BasicConv'>
# cost_agg0.conv1.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.conv1.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.conv1.1: <class 'core.submodule.BasicConv'>
# cost_agg0.conv1.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.conv1.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.conv2: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.conv2.0: <class 'core.submodule.BasicConv'>
# cost_agg0.conv2.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.conv2.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.conv2.1: <class 'core.submodule.BasicConv'>
# cost_agg0.conv2.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.conv2.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.conv3: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.conv3.0: <class 'core.submodule.BasicConv'>
# cost_agg0.conv3.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.conv3.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.conv3.1: <class 'core.submodule.BasicConv'>
# cost_agg0.conv3.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.conv3.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.conv3_up: <class 'core.submodule.BasicConv'>
# cost_agg0.conv3_up.conv: <class 'torch.nn.modules.conv.ConvTranspose3d'>
# cost_agg0.conv3_up.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.conv2_up: <class 'core.submodule.BasicConv'>
# cost_agg0.conv2_up.conv: <class 'torch.nn.modules.conv.ConvTranspose3d'>
# cost_agg0.conv2_up.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.conv1_up: <class 'core.submodule.BasicConv'>
# cost_agg0.conv1_up.conv: <class 'torch.nn.modules.conv.ConvTranspose3d'>
# cost_agg0.conv1_up.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.agg_0: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.agg_0.0: <class 'core.submodule.BasicConv'>
# cost_agg0.agg_0.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.agg_0.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.agg_0.1: <class 'core.submodule.BasicConv'>
# cost_agg0.agg_0.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.agg_0.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.agg_0.2: <class 'core.submodule.BasicConv'>
# cost_agg0.agg_0.2.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.agg_0.2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.agg_1: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.agg_1.0: <class 'core.submodule.BasicConv'>
# cost_agg0.agg_1.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.agg_1.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.agg_1.1: <class 'core.submodule.BasicConv'>
# cost_agg0.agg_1.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.agg_1.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.agg_1.2: <class 'core.submodule.BasicConv'>
# cost_agg0.agg_1.2.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg0.agg_1.2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg0.feature_att_4: <class 'core.submodule.FeatureAtt'>
# cost_agg0.feature_att_4.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.feature_att_4.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg0.feature_att_4.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_4.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg0.feature_att_4.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_8: <class 'core.submodule.FeatureAtt'>
# cost_agg0.feature_att_8.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.feature_att_8.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg0.feature_att_8.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_8.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg0.feature_att_8.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_16: <class 'core.submodule.FeatureAtt'>
# cost_agg0.feature_att_16.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.feature_att_16.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg0.feature_att_16.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_16.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg0.feature_att_16.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_32: <class 'core.submodule.FeatureAtt'>
# cost_agg0.feature_att_32.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.feature_att_32.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg0.feature_att_32.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_32.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg0.feature_att_32.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_up_16: <class 'core.submodule.FeatureAtt'>
# cost_agg0.feature_att_up_16.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.feature_att_up_16.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg0.feature_att_up_16.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_up_16.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg0.feature_att_up_16.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_up_8: <class 'core.submodule.FeatureAtt'>
# cost_agg0.feature_att_up_8.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg0.feature_att_up_8.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg0.feature_att_up_8.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg0.feature_att_up_8.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg0.feature_att_up_8.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1: <class 'core.igev_stereo.hourglass'>
# cost_agg1.conv0: <class 'core.submodule.BasicConv'>
# cost_agg1.conv0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.conv0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.conv1: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.conv1.0: <class 'core.submodule.BasicConv'>
# cost_agg1.conv1.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.conv1.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.conv1.1: <class 'core.submodule.BasicConv'>
# cost_agg1.conv1.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.conv1.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.conv2: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.conv2.0: <class 'core.submodule.BasicConv'>
# cost_agg1.conv2.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.conv2.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.conv2.1: <class 'core.submodule.BasicConv'>
# cost_agg1.conv2.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.conv2.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.conv3: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.conv3.0: <class 'core.submodule.BasicConv'>
# cost_agg1.conv3.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.conv3.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.conv3.1: <class 'core.submodule.BasicConv'>
# cost_agg1.conv3.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.conv3.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.conv3_up: <class 'core.submodule.BasicConv'>
# cost_agg1.conv3_up.conv: <class 'torch.nn.modules.conv.ConvTranspose3d'>
# cost_agg1.conv3_up.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.conv2_up: <class 'core.submodule.BasicConv'>
# cost_agg1.conv2_up.conv: <class 'torch.nn.modules.conv.ConvTranspose3d'>
# cost_agg1.conv2_up.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.conv1_up: <class 'core.submodule.BasicConv'>
# cost_agg1.conv1_up.conv: <class 'torch.nn.modules.conv.ConvTranspose3d'>
# cost_agg1.conv1_up.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.agg_0: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.agg_0.0: <class 'core.submodule.BasicConv'>
# cost_agg1.agg_0.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.agg_0.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.agg_0.1: <class 'core.submodule.BasicConv'>
# cost_agg1.agg_0.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.agg_0.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.agg_0.2: <class 'core.submodule.BasicConv'>
# cost_agg1.agg_0.2.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.agg_0.2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.agg_1: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.agg_1.0: <class 'core.submodule.BasicConv'>
# cost_agg1.agg_1.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.agg_1.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.agg_1.1: <class 'core.submodule.BasicConv'>
# cost_agg1.agg_1.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.agg_1.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.agg_1.2: <class 'core.submodule.BasicConv'>
# cost_agg1.agg_1.2.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg1.agg_1.2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg1.feature_att_4: <class 'core.submodule.FeatureAtt'>
# cost_agg1.feature_att_4.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.feature_att_4.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg1.feature_att_4.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_4.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg1.feature_att_4.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_8: <class 'core.submodule.FeatureAtt'>
# cost_agg1.feature_att_8.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.feature_att_8.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg1.feature_att_8.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_8.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg1.feature_att_8.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_16: <class 'core.submodule.FeatureAtt'>
# cost_agg1.feature_att_16.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.feature_att_16.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg1.feature_att_16.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_16.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg1.feature_att_16.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_32: <class 'core.submodule.FeatureAtt'>
# cost_agg1.feature_att_32.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.feature_att_32.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg1.feature_att_32.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_32.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg1.feature_att_32.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_up_16: <class 'core.submodule.FeatureAtt'>
# cost_agg1.feature_att_up_16.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.feature_att_up_16.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg1.feature_att_up_16.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_up_16.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg1.feature_att_up_16.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_up_8: <class 'core.submodule.FeatureAtt'>
# cost_agg1.feature_att_up_8.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg1.feature_att_up_8.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg1.feature_att_up_8.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg1.feature_att_up_8.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg1.feature_att_up_8.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2: <class 'core.igev_stereo.hourglass'>
# cost_agg2.conv0: <class 'core.submodule.BasicConv'>
# cost_agg2.conv0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.conv0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.conv1: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.conv1.0: <class 'core.submodule.BasicConv'>
# cost_agg2.conv1.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.conv1.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.conv1.1: <class 'core.submodule.BasicConv'>
# cost_agg2.conv1.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.conv1.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.conv2: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.conv2.0: <class 'core.submodule.BasicConv'>
# cost_agg2.conv2.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.conv2.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.conv2.1: <class 'core.submodule.BasicConv'>
# cost_agg2.conv2.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.conv2.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.conv3: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.conv3.0: <class 'core.submodule.BasicConv'>
# cost_agg2.conv3.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.conv3.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.conv3.1: <class 'core.submodule.BasicConv'>
# cost_agg2.conv3.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.conv3.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.conv3_up: <class 'core.submodule.BasicConv'>
# cost_agg2.conv3_up.conv: <class 'torch.nn.modules.conv.ConvTranspose3d'>
# cost_agg2.conv3_up.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.conv2_up: <class 'core.submodule.BasicConv'>
# cost_agg2.conv2_up.conv: <class 'torch.nn.modules.conv.ConvTranspose3d'>
# cost_agg2.conv2_up.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.conv1_up: <class 'core.submodule.BasicConv'>
# cost_agg2.conv1_up.conv: <class 'torch.nn.modules.conv.ConvTranspose3d'>
# cost_agg2.conv1_up.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.agg_0: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.agg_0.0: <class 'core.submodule.BasicConv'>
# cost_agg2.agg_0.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.agg_0.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.agg_0.1: <class 'core.submodule.BasicConv'>
# cost_agg2.agg_0.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.agg_0.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.agg_0.2: <class 'core.submodule.BasicConv'>
# cost_agg2.agg_0.2.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.agg_0.2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.agg_1: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.agg_1.0: <class 'core.submodule.BasicConv'>
# cost_agg2.agg_1.0.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.agg_1.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.agg_1.1: <class 'core.submodule.BasicConv'>
# cost_agg2.agg_1.1.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.agg_1.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.agg_1.2: <class 'core.submodule.BasicConv'>
# cost_agg2.agg_1.2.conv: <class 'torch.nn.modules.conv.Conv3d'>
# cost_agg2.agg_1.2.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm3d'>
# cost_agg2.feature_att_4: <class 'core.submodule.FeatureAtt'>
# cost_agg2.feature_att_4.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.feature_att_4.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg2.feature_att_4.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_4.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg2.feature_att_4.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_8: <class 'core.submodule.FeatureAtt'>
# cost_agg2.feature_att_8.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.feature_att_8.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg2.feature_att_8.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_8.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg2.feature_att_8.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_16: <class 'core.submodule.FeatureAtt'>
# cost_agg2.feature_att_16.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.feature_att_16.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg2.feature_att_16.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_16.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg2.feature_att_16.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_32: <class 'core.submodule.FeatureAtt'>
# cost_agg2.feature_att_32.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.feature_att_32.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg2.feature_att_32.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_32.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg2.feature_att_32.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_up_16: <class 'core.submodule.FeatureAtt'>
# cost_agg2.feature_att_up_16.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.feature_att_up_16.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg2.feature_att_up_16.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_up_16.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg2.feature_att_up_16.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_up_8: <class 'core.submodule.FeatureAtt'>
# cost_agg2.feature_att_up_8.feat_att: <class 'torch.nn.modules.container.Sequential'>
# cost_agg2.feature_att_up_8.feat_att.0: <class 'core.submodule.BasicConv'>
# cost_agg2.feature_att_up_8.feat_att.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# cost_agg2.feature_att_up_8.feat_att.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# cost_agg2.feature_att_up_8.feat_att.1: <class 'torch.nn.modules.conv.Conv2d'>
# classifier: <class 'torch.nn.modules.conv.Conv3d'>
# disp_conv: <class 'torch.nn.modules.container.Sequential'>
# disp_conv.0: <class 'core.submodule.BasicConv'>
# disp_conv.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# disp_conv.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# disp_conv.1: <class 'core.submodule.BasicConv'>
# disp_conv.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# disp_conv.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# selective_conv: <class 'torch.nn.modules.container.Sequential'>
# selective_conv.0: <class 'core.submodule.BasicConv'>
# selective_conv.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# selective_conv.0.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# selective_conv.1: <class 'core.submodule.BasicConv'>
# selective_conv.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# selective_conv.1.IN: <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>
# selective_conv.2: <class 'torch.nn.modules.conv.Conv2d'>

# %%
# Agregar si encuentro mas
target_modules_candidates = [
    ".conv",  # Catches many convolutional layers
    ".conv1",
    ".conv2",
    ".conv3",
    ".q_proj", # If there are query projections in attention
    ".v_proj", # If there are value projections in attention
    ".k_proj", # If there are key projections in attention
    "g_proj", # Example, if some specific projection exists
    "c_proj",
    "attn_q", # If they have custom names like this
    "attn_v",
    "attn_k",
    "gru.weight_ih", # Convolutional GRU weights
    "gru.weight_hh"
]

actual_target_modules = []
for name, module in model.named_modules():
    for candidate in target_modules_candidates:
        if candidate in name and isinstance(module, (nn.Linear, nn.Conv2d)):
            # Filter by actual layer types LoRA can modify
            actual_target_modules.append(name)
            # Break to avoid adding the same module multiple times if multiple candidates match
            break
print(f"Discovered LoRA target modules: {actual_target_modules}")
print(f"Total LoRA target modules: {len(actual_target_modules)}")
# Out:
# Discovered LoRA target modules: ['cnet.conv1.base_layer', 'cnet.conv1.lora_A.default', 'cnet.conv1.lora_B.default', 'cnet.layer1.0.conv1.base_layer.base_layer', 'cnet.layer1.0.conv1.base_layer.lora_A.default', 'cnet.layer1.0.conv1.base_layer.lora_B.default', 'cnet.layer1.0.conv1.lora_A.default.base_layer', 'cnet.layer1.0.conv1.lora_A.default.lora_A.default', 'cnet.layer1.0.conv1.lora_A.default.lora_B.default', 'cnet.layer1.0.conv1.lora_B.default.base_layer', 'cnet.layer1.0.conv1.lora_B.default.lora_A.default', 'cnet.layer1.0.conv1.lora_B.default.lora_B.default', 'cnet.layer1.0.conv2.base_layer.base_layer', 'cnet.layer1.0.conv2.base_layer.lora_A.default', 'cnet.layer1.0.conv2.base_layer.lora_B.default', 'cnet.layer1.0.conv2.lora_A.default.base_layer', 'cnet.layer1.0.conv2.lora_A.default.lora_A.default', 'cnet.layer1.0.conv2.lora_A.default.lora_B.default', 'cnet.layer1.0.conv2.lora_B.default.base_layer', 'cnet.layer1.0.conv2.lora_B.default.lora_A.default', 'cnet.layer1.0.conv2.lora_B.default.lora_B.default', 'cnet.layer1.1.conv1.base_layer.base_layer', 'cnet.layer1.1.conv1.base_layer.lora_A.default', 'cnet.layer1.1.conv1.base_layer.lora_B.default', 'cnet.layer1.1.conv1.lora_A.default.base_layer', 'cnet.layer1.1.conv1.lora_A.default.lora_A.default', 'cnet.layer1.1.conv1.lora_A.default.lora_B.default', 'cnet.layer1.1.conv1.lora_B.default.base_layer', 'cnet.layer1.1.conv1.lora_B.default.lora_A.default', 'cnet.layer1.1.conv1.lora_B.default.lora_B.default', 'cnet.layer1.1.conv2.base_layer.base_layer', 'cnet.layer1.1.conv2.base_layer.lora_A.default', 'cnet.layer1.1.conv2.base_layer.lora_B.default', 'cnet.layer1.1.conv2.lora_A.default.base_layer', 'cnet.layer1.1.conv2.lora_A.default.lora_A.default', 'cnet.layer1.1.conv2.lora_A.default.lora_B.default', 'cnet.layer1.1.conv2.lora_B.default.base_layer', 'cnet.layer1.1.conv2.lora_B.default.lora_A.default', 'cnet.layer1.1.conv2.lora_B.default.lora_B.default', 'cnet.layer2.0.conv1.base_layer.base_layer', 'cnet.layer2.0.conv1.base_layer.lora_A.default', 'cnet.layer2.0.conv1.base_layer.lora_B.default', 'cnet.layer2.0.conv1.lora_A.default.base_layer', 'cnet.layer2.0.conv1.lora_A.default.lora_A.default', 'cnet.layer2.0.conv1.lora_A.default.lora_B.default', 'cnet.layer2.0.conv1.lora_B.default.base_layer', 'cnet.layer2.0.conv1.lora_B.default.lora_A.default', 'cnet.layer2.0.conv1.lora_B.default.lora_B.default', 'cnet.layer2.0.conv2.base_layer.base_layer', 'cnet.layer2.0.conv2.base_layer.lora_A.default', 'cnet.layer2.0.conv2.base_layer.lora_B.default', 'cnet.layer2.0.conv2.lora_A.default.base_layer', 'cnet.layer2.0.conv2.lora_A.default.lora_A.default', 'cnet.layer2.0.conv2.lora_A.default.lora_B.default', 'cnet.layer2.0.conv2.lora_B.default.base_layer', 'cnet.layer2.0.conv2.lora_B.default.lora_A.default', 'cnet.layer2.0.conv2.lora_B.default.lora_B.default', 'cnet.layer2.1.conv1.base_layer.base_layer', 'cnet.layer2.1.conv1.base_layer.lora_A.default', 'cnet.layer2.1.conv1.base_layer.lora_B.default', 'cnet.layer2.1.conv1.lora_A.default.base_layer', 'cnet.layer2.1.conv1.lora_A.default.lora_A.default', 'cnet.layer2.1.conv1.lora_A.default.lora_B.default', 'cnet.layer2.1.conv1.lora_B.default.base_layer', 'cnet.layer2.1.conv1.lora_B.default.lora_A.default', 'cnet.layer2.1.conv1.lora_B.default.lora_B.default', 'cnet.layer2.1.conv2.base_layer.base_layer', 'cnet.layer2.1.conv2.base_layer.lora_A.default', 'cnet.layer2.1.conv2.base_layer.lora_B.default', 'cnet.layer2.1.conv2.lora_A.default.base_layer', 'cnet.layer2.1.conv2.lora_A.default.lora_A.default', 'cnet.layer2.1.conv2.lora_A.default.lora_B.default', 'cnet.layer2.1.conv2.lora_B.default.base_layer', 'cnet.layer2.1.conv2.lora_B.default.lora_A.default', 'cnet.layer2.1.conv2.lora_B.default.lora_B.default', 'cnet.layer3.0.conv1.base_layer.base_layer', 'cnet.layer3.0.conv1.base_layer.lora_A.default', 'cnet.layer3.0.conv1.base_layer.lora_B.default', 'cnet.layer3.0.conv1.lora_A.default.base_layer', 'cnet.layer3.0.conv1.lora_A.default.lora_A.default', 'cnet.layer3.0. ...
# Total LoRA target modules: 513

# %%
from peft import LoraConfig, TaskType, get_peft_model

peft_config = LoraConfig(
    target_modules=actual_target_modules,
    lora_dropout=0.1,
    bias="none",
    r=4,
    lora_alpha=16,
)

# In the paper, section experiments, they set the rank for RVLoRA to 4

# %%
model_with_lora = get_peft_model(model, peft_config)
model_with_lora.print_trainable_parameters()
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/mapping_func.py:73: UserWarning: You are trying to modify a model with PEFT for a second time. If you want to reload the model with a different config, make sure to call `.unload()` before.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/tuners/tuners_utils.py:167: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(
# trainable params: 2,277,076 || all params: 16,805,366 || trainable%: 13.5497
